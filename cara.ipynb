# %% [markdown]
# <a href="https://colab.research.google.com/github/arq62/CARA/blob/master/cara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test cell

# %%
def number_to_word(number):
		number_string = str(number)
	
	#Remove extra zeroes from beginning (e.g. 000001 -> 1)
		number_string.lstrip('0')

#Define required sets of strings for naming numbers
		suffix = ['' , 'thousand', 'million', 'billion', 'trillion', 'quadrillion', 'quintillion', 'sextillion', 'septillion', 'octillion', 'nonillion', 'decillion','Undecillion','Duodecillion','Tredecillion','Quattuordecillion','Quindecillion','Hexdecillion','Septendecillion','Octodecillion','Novemdecillion','Vigintillion','Unvigintillion','Duovigintillion','Trevigintillion','Quattourvigintillion','Quinvigintillion','Hexvigintillion','Septenvigintillion','Octovigintillion','Novemvigintillion','Trigintillion','Untrigintillion','Duotrigintillion']
	
		singledigits = ['','one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine' ]

		teen = ['ten', 'eleven', 'twelve', 'thirteen', 'fourteen', 'fifteen', 'sixteen', 'seventeen', 'eighteen', 'nineteen']

		ty = ['','','twenty', 'thirty', 'forty', 'fifty', 'sixty', 'seventy', 'eighty', 'ninety']

#Converting the number into triad composition form (e.g. 1345 -> 001345)
		m = len(number_string) % 3
		if m == 1:
			number_string = '00' + number_string
		elif m == 2:
			number_string = '0' + number_string

# Counting number of triads (123456 : 2 )
		n = len(number_string)/3
		no_of_triads = int(n)

#Extracting all triads into a list (123456 -> ['123' , '456'])
		triad_list =[]

		for i in range(no_of_triads):
			k = number_string[3*i:3*i +3]
			triad_list.append(k)

#Naming each triad [123 -> one hundred twenty three]

# Matching a single digit to its name (e.g. 5 -> five)
		def digitname(n):
			return singledigits[n]
	
# Naming the hundreds place of triad
		def hundreds(first_digit):
			if first_digit == 0:
				return ""
			else:
				return digitname(first_digit)+' '+ 'hundred '

# Naming the tens and units places of triad
		def tens_and_units(second_digit,third_digit):
			if second_digit == 0:
				return digitname(third_digit)
			elif second_digit == 1:
				return teen[third_digit]
			else:
				tens_place = ty[second_digit]		
				units_place = digitname(third_digit)
				return tens_place + ' ' +  units_place
		
# Naming a triad
		def triad_name(triad):
			hundred = triad[0]
			ten = triad[1]
			unit = triad[2]
			hundreds_place = hundreds(int(hundred))
			tens_units_place = tens_and_units(int(ten),int(unit))
			return hundreds_place +tens_units_place

# Suffixing a triad place value (In 123000; 123-> one hundred twenty three thousand)
		number_spelling =''
		for i in range(no_of_triads):
			k = triad_list[i]
			if triad_list[i] != '000':
				number_spelling += (triad_name(k)+' ' + suffix[no_of_triads - i -1] + ' ')

		return number_spelling

# Counting length of spelling

def namelength(s):
	k = number_to_word(s)
	spelling_length = len(k) - k.count(' ')
	return spelling_length


# For each number, finds spelling length (after converting to spelling first) and then proceeds with it as next number in loop
# Outputs the final number obtained after algorithm is repeated sufficiently (i.e. before entering an infinite loop)
def cara_loop(n):
	while namelength(n) != n:
		n = namelength(n)
	return n

# Taking input for the upper bound of the range of natural numbers to test
test_range = int(input('Range? ')) +1
true_outputs = 0

# Loop checking convergence, i.e. whether output of the loop is 4, for each integer and counting the number of integers satisfying it
for i in range(1,test_range):
	if cara_loop(i) == 4:
		true_outputs +=1

# Displaying output (number of natural numbers in the range satisfying the condition)
print('CARA is valid for {} numbers in given range.'.format(true_outputs))


#import matplotlib.pyplot as plt


#x = range(0,99,3)
#y = []
#for i in x:
#	y.append(namelength(10**i))

#z=int(input('exp'))
#j=10**z
#x=range(1,j)

#y=[]
#for i in x:
	
#	y.append(namelength(i))




#plt.scatter(x,y)
#plt.xlabel("number")
#plt.ylabel("length")
#plt.show()
# Out:
# Range? 1000
# CARA is valid for 1000 numbers in given range.

# %% [markdown]
# Regression

# %%
def number_to_word(number):
		number_string = str(number)
	
	#Remove extra zeroes from beginning (e.g. 000001 -> 1)
		number_string.lstrip('0')

#Define required sets of strings for naming numbers
		suffix = ['' , 'thousand', 'million', 'billion', 'trillion', 'quadrillion', 'quintillion', 'sextillion', 'septillion', 'octillion', 'nonillion', 'decillion','Undecillion','Duodecillion','Tredecillion','Quattuordecillion','Quindecillion','Hexdecillion','Septendecillion','Octodecillion','Novemdecillion','Vigintillion','Unvigintillion','Duovigintillion','Trevigintillion','Quattourvigintillion','Quinvigintillion','Hexvigintillion','Septenvigintillion','Octovigintillion','Novemvigintillion','Trigintillion','Untrigintillion','Duotrigintillion']
	
		singledigits = ['','one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine' ]

		teen = ['ten', 'eleven', 'twelve', 'thirteen', 'fourteen', 'fifteen', 'sixteen', 'seventeen', 'eighteen', 'nineteen']

		ty = ['','','twenty', 'thirty', 'forty', 'fifty', 'sixty', 'seventy', 'eighty', 'ninety']

#Converting the number into triad composition form (e.g. 1345 -> 001345)
		m = len(number_string) % 3
		if m == 1:
			number_string = '00' + number_string
		elif m == 2:
			number_string = '0' + number_string

# Counting number of triads (123456 : 2 )
		n = len(number_string)/3
		no_of_triads = int(n)

#Extracting all triads into a list (123456 -> ['123' , '456'])
		triad_list =[]

		for i in range(no_of_triads):
			k = number_string[3*i:3*i +3]
			triad_list.append(k)

#Naming each triad [123 -> one hundred twenty three]

# Matching a single digit to its name (e.g. 5 -> five)
		def digitname(n):
			return singledigits[n]
	
# Naming the hundreds place of triad
		def hundreds(first_digit):
			if first_digit == 0:
				return ""
			else:
				return digitname(first_digit)+' '+ 'hundred '

# Naming the tens and units places of triad
		def tens_and_units(second_digit,third_digit):
			if second_digit == 0:
				return digitname(third_digit)
			elif second_digit == 1:
				return teen[third_digit]
			else:
				tens_place = ty[second_digit]		
				units_place = digitname(third_digit)
				return tens_place + ' ' +  units_place
		
# Naming a triad
		def triad_name(triad):
			hundred = triad[0]
			ten = triad[1]
			unit = triad[2]
			hundreds_place = hundreds(int(hundred))
			tens_units_place = tens_and_units(int(ten),int(unit))
			return hundreds_place +tens_units_place

# Suffixing a triad place value (In 123000; 123-> one hundred twenty three thousand)
		number_spelling =''
		for i in range(no_of_triads):
			k = triad_list[i]
			if triad_list[i] != '000':
				number_spelling += (triad_name(k)+' ' + suffix[no_of_triads - i -1] + ' ')

		return number_spelling

# Counting length of spelling

def namelength(s):
	k = number_to_word(s)
	spelling_length = len(k) - k.count(' ')
	return spelling_length

import matplotlib.pyplot as plt
from scipy import stats

x = range(3,99,3)
y = []
for i in x:
	y.append(namelength(10**i)-3)





slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)
print("slope: %f    intercept: %f" % (slope, intercept))

print("R-squared: %f" % r_value**2)

plt.plot(x,y,'o', label ="N-illion")
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.legend()
plt.xlabel("log(N-illion)")
plt.ylabel("length")
plt.show()
# Out:
# slope: 0.099829    intercept: 7.683468
# R-squared: 0.708193

# %% [markdown]
# Graph cell

# %%
def number_to_word(number):
		number_string = str(number)
	
	#Remove extra zeroes from beginning (e.g. 000001 -> 1)
		number_string.lstrip('0')

#Define required sets of strings for naming numbers
		suffix = ['' , 'thousand', 'million', 'billion', 'trillion', 'quadrillion', 'quintillion', 'sextillion', 'septillion', 'octillion', 'nonillion', 'decillion','Undecillion','Duodecillion','Tredecillion','Quattuordecillion','Quindecillion','Hexdecillion','Septendecillion','Octodecillion','Novemdecillion','Vigintillion','Unvigintillion','Duovigintillion','Trevigintillion','Quattourvigintillion','Quinvigintillion','Hexvigintillion','Septenvigintillion','Octovigintillion','Novemvigintillion','Trigintillion','Untrigintillion','Duotrigintillion']
	
		singledigits = ['','one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine' ]

		teen = ['ten', 'eleven', 'twelve', 'thirteen', 'fourteen', 'fifteen', 'sixteen', 'seventeen', 'eighteen', 'nineteen']

		ty = ['','','twenty', 'thirty', 'forty', 'fifty', 'sixty', 'seventy', 'eighty', 'ninety']

#Converting the number into triad composition form (e.g. 1345 -> 001345)
		m = len(number_string) % 3
		if m == 1:
			number_string = '00' + number_string
		elif m == 2:
			number_string = '0' + number_string

# Counting number of triads (123456 : 2 )
		n = len(number_string)/3
		no_of_triads = int(n)

#Extracting all triads into a list (123456 -> ['123' , '456'])
		triad_list =[]

		for i in range(no_of_triads):
			k = number_string[3*i:3*i +3]
			triad_list.append(k)

#Naming each triad [123 -> one hundred twenty three]

# Matching a single digit to its name (e.g. 5 -> five)
		def digitname(n):
			return singledigits[n]
	
# Naming the hundreds place of triad
		def hundreds(first_digit):
			if first_digit == 0:
				return ""
			else:
				return digitname(first_digit)+' '+ 'hundred '

# Naming the tens and units places of triad
		def tens_and_units(second_digit,third_digit):
			if second_digit == 0:
				return digitname(third_digit)
			elif second_digit == 1:
				return teen[third_digit]
			else:
				tens_place = ty[second_digit]		
				units_place = digitname(third_digit)
				return tens_place + ' ' +  units_place
		
# Naming a triad
		def triad_name(triad):
			hundred = triad[0]
			ten = triad[1]
			unit = triad[2]
			hundreds_place = hundreds(int(hundred))
			tens_units_place = tens_and_units(int(ten),int(unit))
			return hundreds_place +tens_units_place

# Suffixing a triad place value (In 123000; 123-> one hundred twenty three thousand)
		number_spelling =''
		for i in range(no_of_triads):
			k = triad_list[i]
			if triad_list[i] != '000':
				number_spelling += (triad_name(k)+' ' + suffix[no_of_triads - i -1] + ' ')

		return number_spelling

# Counting length of spelling

def namelength(s):
	k = number_to_word(s)
	spelling_length = len(k) - k.count(' ')
	return spelling_length

import matplotlib.pyplot as plt
from scipy import stats

x = range(100,1000)
y = []
for i in x:
	y.append(namelength(i))






plt.plot(x,y,color="red", label="y=f1(x)")
plt.plot(x,x)

plt.legend()
plt.xlabel("Two digit numbers")
plt.ylabel("Spelling length")

plt.show()
